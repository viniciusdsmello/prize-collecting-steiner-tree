# %% [markdown]
# # Prize-Collecting Steiner Tree (PCSTP)

# %% [markdown]
# ## Libs Importing

# %%
import sys
import os

sys.path.insert(1, os.path.realpath(os.path.pardir))

# %%
from pcstp.instances.generator import generate_random_steiner
from pcstp.utils.draw import draw_steiner_graph

# %% [markdown]
# ## PCSTP Instance Generator

# %%
G, (nodes, edges, position_matrix, edges_cost, terminals, prizes) = generate_random_steiner(
    num_nodes=8,
    num_edges=12,
    max_node_degree=10,
    min_prize=0,
    max_prize=100,
    num_terminals=3,
    min_edge_cost=0,
    max_edge_cost=10,
    cost_as_length=False,
    max_iter=100,
    seed=3
)

draw_steiner_graph(G)
# Out:
# terminals:  (3,)
# prizes:  (3,)
